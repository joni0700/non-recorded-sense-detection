# %% [markdown]
# ### Pre-sort samples
# This notebook filters the model predictions.
# It filters usages that have incomplete headwords and sorts the remaining usages by theire similarity to the nearest sense.
#
# ### Usage
# Set the file paths in the second cell to the predictions of the models you want to filter.

# %%
import csv
from spacy.symbols import IS_PUNCT
import json
from nltk.corpus import wordnet as wn
import pandas as pd

# %%
historical_sample_file = "../data/outputs/model_predictions/SAMPLE_ccoha1_token-wordnet_sense_id_example[4]_embeddings.json"
modern_sample_file = "../data/outputs/model_predictions/SAMPLE_eng_news_2020_1M-sentences-wordnet_sense_id_example[4]_embeddings.json"


output_file = f"../data/outputs/annotation_phase_2/eng_combined_data.json"

# %%
with open(historical_sample_file, "r") as f:
    historical_sample = json.load(f)

    complete_historical = []

    for lemma in historical_sample:
        for usage in historical_sample[lemma]:
            if usage['empty_synsets'] == 0:
                complete_historical.append({
                    "lemma": lemma,
                    "sentence": usage['usage']['sentence'],
                    "target": usage['usage']['target'],
                    "highest_similarity": usage['usage']['closest'][0][1],
                    "corpus_id": f"ccoha1"
                })

complete_historical = pd.DataFrame(complete_historical)
complete_historical = complete_historical.drop_duplicates(subset=['sentence'])
complete_historical = complete_historical.sort_values(by=['highest_similarity'])

print(complete_historical.shape)
display(complete_historical.head())

historical_dict = complete_historical.to_dict(orient='records')
display(historical_dict[0])
# Out:
# (11, 5)
#            lemma                                           sentence  \
# 8           wage  This came barely 24 hours after Governor Fayem...
# 9    resuscitate  Following mounting pressure from the Bretton W...
# 3  qualification  The majority of the squad agreed to a 12.5 per...
# 6        segment  The addition of 360 Blue to Natural Retreats' ...
# 1   instrumental  The Red Bull junior program has played an inst...
#
#        target  highest_similarity corpus_id
# 8  [138, 142]            0.225902    ccoha1
# 9  [191, 202]            0.228190    ccoha1
# 3  [115, 128]            0.258717    ccoha1
# 6  [166, 173]            0.285176    ccoha1
# 1    [42, 54]            0.288447    ccoha1
# {'lemma': 'wage',
#  'sentence': 'This came barely 24 hours after Governor Fayemis statewide broadcast where he appealed to wellmeaning Ekiti stakeholders to join hands in waging war against coronavirus.',
#  'target': [138, 142],
#  'highest_similarity': 0.22590182295190173,
#  'corpus_id': 'ccoha1'}

# %%
with open(modern_sample_file, "r") as f:
    modern_sample = json.load(f)

    complete_modern = []

    for lemma in modern_sample:
        for usage in modern_sample[lemma]:
            if usage['empty_synsets'] == 0:
                complete_modern.append({
                    "lemma": lemma,
                    "sentence": usage['usage']['sentence'],
                    "target": usage['usage']['target'],
                    "highest_similarity": usage['usage']['closest'][0][1],
                    "corpus_id": f"leipzig_eng_news"
                })

complete_modern = pd.DataFrame(complete_modern)
complete_modern = complete_modern.drop_duplicates(subset=['sentence'])
complete_modern = complete_modern.sort_values(by=['highest_similarity'])

print(complete_modern.shape)
display(complete_modern.head())

modern_dict = complete_modern.to_dict(orient='records')
display(modern_dict[0])
# Out:
# (259, 5)
#              lemma                                           sentence  \
# 70   qualification  Slovan Bratislava's Champions League qualifica...
# 68   qualification  Streichs team is currently eighth in the 18tea...
# 67   qualification  But they have fallen away badly, winning only ...
# 66   qualification  The bid for Aberdeens first Scottish Cup since...
# 195           wage  Davis gained fame as a state legislator by wag...
#
#          target  highest_similarity         corpus_id
# 70     [37, 50]            0.173049  leipzig_eng_news
# 68   [120, 133]            0.188805  leipzig_eng_news
# 67   [144, 157]            0.192252  leipzig_eng_news
# 66     [65, 78]            0.194470  leipzig_eng_news
# 195    [43, 47]            0.194945  leipzig_eng_news
# {'lemma': 'qualification',
#  'sentence': "Slovan Bratislava's Champions League qualification tie against Faroe Islands side KI Klaksvik has been cancelled after a player from the Slovakian club tested positive for COVID19, European soccer's governing body UEFA said on Saturday.",
#  'target': [37, 50],
#  'highest_similarity': 0.17304900400543594,
#  'corpus_id': 'leipzig_eng_news'}

# %%
# combine both datasets
combined_data = historical_dict + modern_dict
combined_data = pd.DataFrame(combined_data)
combined_data = combined_data.drop_duplicates(subset=['lemma', 'sentence'])
combined_data = combined_data.sort_values(by=['corpus_id', 'highest_similarity'])

combined_data.to_json(output_file, orient='records', indent=4)

print(combined_data.shape)
display(combined_data.head())
# Out:
# (4531, 5)
#      lemma                                           sentence      target  \
# 0       et  hugade Kipare f underrttelse om tw stycke goda...    [73, 75]
# 1       et  Nsta Michaeli stundas at fra i sjelfwa Staben ...    [46, 48]
# 2       et  en bestickning til Kejsaren i China den bestod...    [88, 90]
# 3     tank  Lsare mste gista sig till Skriftens innehll , ...  [157, 164]
# 4  patriot  Till Skellefte r lgenhet fr Fraktgods och Patz...  [100, 109]
#
#    highest_similarity  corpus_id
# 0            0.034321  kubhist2a
# 1            0.052518  kubhist2a
# 2            0.069148  kubhist2a
# 3            0.072811  kubhist2a
# 4            0.076772  kubhist2a

# %% [markdown]
# ---

# %%
complete_synset_usages = []
with open(sample_file) as f:
    sample = json.load(f)

    for lemma in sample:
       # print(lemma)
        for usage in sample[lemma]: # ["unassigned_usages"]:
#            #u = usage['usage']
            if usage['empty_synsets'] == 0:
                complete_synset_usages.append({
                    "lemma": lemma,
                    "sentence": usage['usage']['sentence'],
                    "target": usage['usage']['target'],
                    "highest_similarity": usage['usage']['closest'][0][1],
                    #"corpus_id": "leipzig_eng_news",
                    "corpus_id": f"ccoha1"
                })
# sort by similarity
complete_synset_usages = sorted(complete_synset_usages, key=lambda x: x['highest_similarity'])
print(f"Number of usages with no missing synsets: {len(complete_synset_usages)}")
display(pd.DataFrame(complete_synset_usages).head(15))
# remove duplicate sentences
df = pd.DataFrame(complete_synset_usages).drop_duplicates(subset=['sentence'])
print(f"Number of usages with no missing synsets and no duplicate sentences: {len(df)}")
display(df.head(15))
# write backt to dict
complete_synset_usages = df.to_dict('records')
# Out:
# Number of usages with no missing synsets: 170
#         lemma                                           sentence      target  \
# 0      unused  During my voyage , affrighted by the dangers w...    [93, 99]
# 1     trample  It were less cruel for me to have slain her , ...  [168, 175]
# 2    strongly  When the wind blows strongly from the north an...    [20, 28]
# 3    strongly  When the wind blows strongly from the north an...    [20, 28]
# 4      warmly  Besides , had it been warmly espoused at the f...    [22, 28]
# 5       shirk  to the river and washed , first for , it was i...  [282, 287]
# 6     trample  Silence in the mean time held forth largely on...  [128, 135]
# 7   different  The terms of office of the Regents expire at d...    [45, 54]
# 8   fashioned  But it ought to be known that , on this occasi...  [140, 149]
# 9   different  Three parties had at different times visited P...    [21, 30]
# 10  immediate  You are so direct and immediate , my beloved f...    [22, 31]
# 11   conceive  The words of my father occurred to me more tha...    [69, 77]
# 12   strongly  Mrs. Layton leant against the window , her han...  [109, 117]
# 13     fabric  fabrics Of man 's pride , lay crumbling ' neat...      [0, 6]
# 14  different  Acts have been passed at different times to fa...    [25, 34]
#
#     highest_similarity corpus_id
# 0             0.223719    ccoha1
# 1             0.251587    ccoha1
# 2             0.257914    ccoha1
# 3             0.257914    ccoha1
# 4             0.267301    ccoha1
# 5             0.267521    ccoha1
# 6             0.269351    ccoha1
# 7             0.277505    ccoha1
# 8             0.285888    ccoha1
# 9             0.293393    ccoha1
# 10            0.298968    ccoha1
# 11            0.301066    ccoha1
# 12            0.301293    ccoha1
# 13            0.303192    ccoha1
# 14            0.303786    ccoha1
# Number of usages with no missing synsets and no duplicate sentences: 165
#         lemma                                           sentence      target  \
# 0      unused  During my voyage , affrighted by the dangers w...    [93, 99]
# 1     trample  It were less cruel for me to have slain her , ...  [168, 175]
# 2    strongly  When the wind blows strongly from the north an...    [20, 28]
# 4      warmly  Besides , had it been warmly espoused at the f...    [22, 28]
# 5       shirk  to the river and washed , first for , it was i...  [282, 287]
# 6     trample  Silence in the mean time held forth largely on...  [128, 135]
# 7   different  The terms of office of the Regents expire at d...    [45, 54]
# 8   fashioned  But it ought to be known that , on this occasi...  [140, 149]
# 9   different  Three parties had at different times visited P...    [21, 30]
# 10  immediate  You are so direct and immediate , my beloved f...    [22, 31]
# 11   conceive  The words of my father occurred to me more tha...    [69, 77]
# 12   strongly  Mrs. Layton leant against the window , her han...  [109, 117]
# 13     fabric  fabrics Of man 's pride , lay crumbling ' neat...      [0, 6]
# 14  different  Acts have been passed at different times to fa...    [25, 34]
# 15     unused  he said , with a modest air , unaccustomed as ...    [76, 82]
#
#     highest_similarity corpus_id
# 0             0.223719    ccoha1
# 1             0.251587    ccoha1
# 2             0.257914    ccoha1
# 4             0.267301    ccoha1
# 5             0.267521    ccoha1
# 6             0.269351    ccoha1
# 7             0.277505    ccoha1
# 8             0.285888    ccoha1
# 9             0.293393    ccoha1
# 10            0.298968    ccoha1
# 11            0.301066    ccoha1
# 12            0.301293    ccoha1
# 13            0.303192    ccoha1
# 14            0.303786    ccoha1
# 15            0.307341    ccoha1

# %%
# group by lemma
sample = {}
total_samples = 0
for usage in complete_synset_usages:
    if usage['lemma'] not in sample:
        sample[usage['lemma']] = {
            "samples" : 0,
            "unassigned_usages": [],
        }

instances_size = 0

for usage in complete_synset_usages:
    if instances_size > 900:
        break
    
    
    if sample[usage['lemma']]['samples'] < 8:
        instances_size += len(wn.synsets(usage['lemma']))
        sample[usage['lemma']]['samples'] += 1
        sample[usage['lemma']]['unassigned_usages'].append(usage)
        total_samples += 1


# remove lemmas with no samples
sample = {lemma: sample[lemma] for lemma in sample if sample[lemma]['samples'] > 0}

print(f"Number of lemmas with samples: {len(sample)}")
print(f"Number of instances: {instances_size}")
print(f"Number of samples: {total_samples}")
display(sample)
# Out:
# Number of lemmas with samples: 49
# Number of instances: 381
# Number of samples: 106
# {'unused': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'unused',
#     'sentence': 'During my voyage , affrighted by the dangers which surrounded me , and to which I was wholly unused , I heartily repented of my resolution but now , methinks , I have reason to rejoice at my perseverance .',
#     'target': [93, 99],
#     'highest_similarity': 0.2237192327980831,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'unused',
#     'sentence': 'he said , with a modest air , unaccustomed as I am to public speaking , and unused as I am to receiving from ladies assurances of a character similar to There , now !',
#     'target': [76, 82],
#     'highest_similarity': 0.3073406431049281,
#     'corpus_id': 'ccoha1'}]},
#  'trample': {'samples': 8,
#   'unassigned_usages': [{'lemma': 'trample',
#     'sentence': 'It were less cruel for me to have slain her , after the brutal fashion of our people , than to have taught her hopes and feelings on which the cruel necessity makes me trample , as if I cared for them nothing .',
#     'target': [168, 175],
#     'highest_similarity': 0.25158705341177307,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': "Silence in the mean time held forth largely on the importance of standing up for one 's rights , and not letting one 's self be trampled on .",
#     'target': [128, 135],
#     'highest_similarity': 0.2693508712717259,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': "Leoni Then rest assured thou art The great avenger of an injured girl , Whose honor has been trampled on by one Who now inherits all the misery of his guilt In Hell 's deep gulf , where hope can never come .",
#     'target': [93, 100],
#     'highest_similarity': 0.3192894039231814,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': 'His noble mind could scarcely conceive of that malignity which could trample upon a solitary and defenceless individual , placed by accident in the hands of numerous personal enemies .',
#     'target': [69, 76],
#     'highest_similarity': 0.32161542897503753,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': 'What follows , may teach him , my mother , to show pity on the vanquished , and not to trample on the widow and those who are without fathers .',
#     'target': [87, 94],
#     'highest_similarity': 0.3500820309706029,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': 'In a progress with such principles , every thing that is worth living for is apt to be trampled in the dust , and the march of the nation is in quick time towards barbarism and dishonor .',
#     'target': [87, 94],
#     'highest_similarity': 0.3514674155997425,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': "See the rose on that round cheek , it might teach that same haughty loyalist , could he see her now , what kind of hearts ' t is that we patriots wear , whose strength they think to trample .",
#     'target': [182, 189],
#     'highest_similarity': 0.3654751537801301,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'trample',
#     'sentence': 'Helen , you are trampling under foot your birthright in the Church of Christ !',
#     'target': [16, 23],
#     'highest_similarity': 0.38730435501752375,
#     'corpus_id': 'ccoha1'}]},
#  'strongly': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'strongly',
#     'sentence': 'When the wind blows strongly from the north and northeast , the sea , in the course of eight days , will destroy the work of years .',
#     'target': [20, 28],
#     'highest_similarity': 0.2579138987733352,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'strongly',
#     'sentence': "Mrs. Layton leant against the window , her handkerchief at her eyes , and her back to the light , which fell strongly on the stranger 's face .",
#     'target': [109, 117],
#     'highest_similarity': 0.30129299361633644,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'strongly',
#     'sentence': 'The furniture , and among the rest , a large chest strongly fastened , was removed into an adjoining room which was otherwise unoccupied , and which was usually kept locked .',
#     'target': [51, 59],
#     'highest_similarity': 0.3637514640404835,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'strongly',
#     'sentence': 'Then , with the maul , after repeatedly smiting the upper end of this iron rod , he placed the blunted needle endwise on the top of it , and less strongly hammered that , several times , the mate still holding the rod as before .',
#     'target': [146, 154],
#     'highest_similarity': 0.37882091096845716,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'strongly',
#     'sentence': 'When wellestablished , they may be transplanted into the bed or border where they are to remain , z and will flower strongly the next year .',
#     'target': [116, 124],
#     'highest_similarity': 0.39856716257778413,
#     'corpus_id': 'ccoha1'}]},
#  'warmly': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'warmly',
#     'sentence': 'Besides , had it been warmly espoused at the first by either , it would haveLafayette q s views of the Colonization Society .',
#     'target': [22, 28],
#     'highest_similarity': 0.2673011251877548,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'warmly',
#     'sentence': 'was warmly attached but time and tide soon separated the cousins , and the last farewell , and waving of handkerchiefs , were exchanged .',
#     'target': [4, 10],
#     'highest_similarity': 0.3611211644374508,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'warmly',
#     'sentence': "was warmly seconded by Samuel Adams , who had thus far remained silent , contrary to his usual custom in deliberative bodies , for , as be said , having doubts and difficulties respecting some parts of the proposed constitution , he chose rather to be an auditor than an objector . '",
#     'target': [4, 10],
#     'highest_similarity': 0.3611211644374508,
#     'corpus_id': 'ccoha1'}]},
#  'shirk': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'shirk',
#     'sentence': 'to the river and washed , first for , it was in vain to think of swimming there , at a season of the year , when the fresh waters , all about , were full of sawdust , slabs , mud turtles , and floating timber to say nothing of water snakes , which were far more terrible to me than shirks .',
#     'target': [282, 287],
#     'highest_similarity': 0.26752068171625965,
#     'corpus_id': 'ccoha1'}]},
#  'different': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'different',
#     'sentence': 'The terms of office of the Regents expire at different periods , which further complicates the composition of the Board .',
#     'target': [45, 54],
#     'highest_similarity': 0.27750521913668547,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'different',
#     'sentence': 'Three parties had at different times visited Petra , but neither of them had passed through the land of Idumea and , according to the reports of the few travellers who had crossed its borders , the Bedouins who roamed over the dreary sands of Idumea were the most ferocious tribe of the desert race .',
#     'target': [21, 30],
#     'highest_similarity': 0.2933925506043917,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'different',
#     'sentence': 'Acts have been passed at different times to facilitate this object and the whole amount of proceeds arising from these sales is now pledged for the gradual payment of the public debt , till it shall be extinguished .',
#     'target': [25, 34],
#     'highest_similarity': 0.3037860757456548,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'different',
#     'sentence': 'The colonies attempted to form some union among themselves at different times .',
#     'target': [62, 71],
#     'highest_similarity': 0.3475234693512624,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'different',
#     'sentence': 'Tariff and antitariff views and the like , have had less to do in producing the commotions which have convulsed our country at different times , than many are aware of .',
#     'target': [127, 136],
#     'highest_similarity': 0.39994191894356623,
#     'corpus_id': 'ccoha1'}]},
#  'fashioned': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'fashioned',
#     'sentence': "But it ought to be known that , on this occasion , O'Halloran regulated the proceedings according to his own fancy , which was somewhat old fashioned .",
#     'target': [140, 149],
#     'highest_similarity': 0.28588818083470424,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'fashioned',
#     'sentence': 'The view of the prairie stretching in airy undulations far away , and of the eddying current of the Mississippi , there as everywhere deep and majestic , with its banks skirted with autumncolored foliage , was enough to commend the old fashioned system of stages to more general use .',
#     'target': [236, 245],
#     'highest_similarity': 0.3503692511265288,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'fashioned',
#     'sentence': 'But many members of the Equal Rights Party were very suspicious of the political honesty of Tammany , and particularly so long as they saw that the Old hunkers , as the old fashioned unchanged Democrats were nicknamed , had any power there .',
#     'target': [173, 182],
#     'highest_similarity': 0.3522187589407052,
#     'corpus_id': 'ccoha1'}]},
#  'immediate': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'immediate',
#     'sentence': 'You are so direct and immediate , my beloved friend !',
#     'target': [22, 31],
#     'highest_similarity': 0.298968253790859,
#     'corpus_id': 'ccoha1'}]},
#  'conceive': {'samples': 8,
#   'unassigned_usages': [{'lemma': 'conceive',
#     'sentence': 'The words of my father occurred to me more than once but I could not conceive that such a calamity was the work of Providence for some good or wise purpose .',
#     'target': [69, 77],
#     'highest_similarity': 0.30106625733137826,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'We are at a loss to conceive why these faunae should be associated into one great zoological province , from which the Arctic fauna is excluded , seeing that so many of the species found in the latter range so extensively through the regions assigned to the former .',
#     'target': [20, 28],
#     'highest_similarity': 0.3167560550926257,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'Yet it was difficult to conceive of their grandeur till we approached and touched the columns .',
#     'target': [24, 32],
#     'highest_similarity': 0.34879062432944713,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'But when we attempt to conceive of him , i. e. think , talk , or reason of him as a being with attributes , then we form a conception of him which is very different from the idea , and which is therefore imperfect always , and most likely false .',
#     'target': [23, 31],
#     'highest_similarity': 0.35043003674629847,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'Maria grasped her hand she looked in her countenance and saw that her heart was full , and she could not resolve to increase its sorrow by disclaiming that tender relationship she had hitherto conceived herself to bear to the affectionate guardian and cherisher of her childhood .',
#     'target': [193, 201],
#     'highest_similarity': 0.3511694218939989,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'The latter could not conceive why the boy should sometimes leave his plough in the furrow , and sit upon a hillock , gazing curiously and admiringly upon',
#     'target': [21, 29],
#     'highest_similarity': 0.35132559366282806,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'After this I could conceive of the sentiment which animated Petrarch of Italy , when he refused the offer of the pontiff , his patron and declined receiving in marriage that Laura , the mere thought of whose displeasure could deprive him of peace and of health .',
#     'target': [19, 27],
#     'highest_similarity': 0.3567778480616551,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'conceive',
#     'sentence': 'As Sir Geoffrey seemed to be in great torture , our party hastened homeward with all the sail their boat could carry , in order as soon as possible to procure for him more comfortable accommodations and surgical assistance for they did not conceive it safe or',
#     'target': [240, 248],
#     'highest_similarity': 0.35913261748086683,
#     'corpus_id': 'ccoha1'}]},
#  'fabric': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'fabric',
#     'sentence': "fabrics Of man 's pride , lay crumbling ' neath my feet fallen Desolate like thy fortunes , mighty city .",
#     'target': [0, 6],
#     'highest_similarity': 0.30319202176167653,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'fabric',
#     'sentence': 'fabric that was to be reared the seven men proceed to constitute the church and out of the sermons , and the seven men , and the church , the spirit of liberty passed forth to embody itself in a constitution .',
#     'target': [0, 6],
#     'highest_similarity': 0.3273785405192761,
#     'corpus_id': 'ccoha1'}]},
#  'wage': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'wage',
#     'sentence': 'They have feared lest , in waging war upon this new movement , they should seem to stand in the same category with James Watson Webb , and other kindred spirits , whose heartless and cowardly attacks , have received , what they merited , the deep contempt of the upright throughout the land .',
#     'target': [27, 31],
#     'highest_similarity': 0.31634601199842644,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'wage',
#     'sentence': 'We must wage war against him till he is humbled or subdued .',
#     'target': [8, 12],
#     'highest_similarity': 0.32588569978899934,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'wage',
#     'sentence': 'Alas , miserable youth , you know by sad , by woeful experience , the living truth of our text , that the wages of Sin is Death .',
#     'target': [106, 110],
#     'highest_similarity': 0.3792472037944353,
#     'corpus_id': 'ccoha1'}]},
#  'awaken': {'samples': 8,
#   'unassigned_usages': [{'lemma': 'awaken',
#     'sentence': 'the feelings awakened in the bosoms of those thus conveying to the grave the mortal remains of one whom they had known in life Must they not have heard within their own breasts a voice loud as that of an archangel , saying , Be ye also ready !',
#     'target': [13, 19],
#     'highest_similarity': 0.32886174763965376,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'This step made room for another , and a new desire was awakened in the heart of the mother to remain near her child .',
#     'target': [55, 61],
#     'highest_similarity': 0.33059965310063655,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'show that , as it is the result of false social influences , it is illfounded and may be removed , and in its place a true and noble sentiment of Union and Brotherhood awakened .',
#     'target': [168, 174],
#     'highest_similarity': 0.33335770420570776,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'England will have to come out of that England , too terribly awakened at last , is every where preparing to come out of that .',
#     'target': [61, 67],
#     'highest_similarity': 0.3432646873435376,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'They are twentyeight in number and the undcrgradnates having the privilege of selecting any two of them , a pirit of competition must be awakened which will greatly add to their usefulness .',
#     'target': [137, 143],
#     'highest_similarity': 0.3503609139188899,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'Pardon me if I express some of the reflections awakened in my own mind .',
#     'target': [47, 53],
#     'highest_similarity': 0.35205179127029534,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'As their number has increased , suspicion and jealousy have been awakened against them they have fallen under the ban of the patriarch , and occasionally have been imprisoned or sent into exile under false pretences .',
#     'target': [65, 71],
#     'highest_similarity': 0.35227491774551173,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'awaken',
#     'sentence': 'might have called forth anger and awakened in her heart the spirit of resistance this , on the contrary , appealed to her better reason , and voiceless in its wholesome admonition , led her to selfblame and selfaccusation .',
#     'target': [34, 40],
#     'highest_similarity': 0.3575035986338602,
#     'corpus_id': 'ccoha1'}]},
#  'installation': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'installation',
#     'sentence': 'After attempting , by the installation of Manco Capac as Inca , to control the people and subject them to his will , Pizarro returned to the coast and founded the city of Lima , where he was assassinated in 1541 , nine years after the seizure of the Inca .',
#     'target': [26, 38],
#     'highest_similarity': 0.32957815517488015,
#     'corpus_id': 'ccoha1'}]},
#  'persuade': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'persuade',
#     'sentence': 'If the principles on which these observations are founded be just , as I persuade myself they are , and they be applied as a criterion to the several state constitutions , and to the federal constitution , it will be found',
#     'target': [73, 81],
#     'highest_similarity': 0.33842192082111433,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'persuade',
#     'sentence': 'were thus positively forbidden to meet had our fathers spoken their real sentiments , I am persuaded they would both of them have approved our affection for each other .',
#     'target': [91, 99],
#     'highest_similarity': 0.4015038713253701,
#     'corpus_id': 'ccoha1'}]},
#  'destine': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'destine',
#     'sentence': "Valmore I implored Madam de Cerval to dispose of the twenty thousand louis destined for me , in favour of Mr. D'Anglade , and , can you believe it ?",
#     'target': [75, 82],
#     'highest_similarity': 0.3399502449753236,
#     'corpus_id': 'ccoha1'}]},
#  'knead': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'knead',
#     'sentence': 'recalling these trifles , and rendering them more misty and unsubstantial than at first by the quantity of speculative musing thus kneaded in with them .',
#     'target': [131, 136],
#     'highest_similarity': 0.34151907052428293,
#     'corpus_id': 'ccoha1'}]},
#  'clank': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'clank',
#     'sentence': 'His one eye winked knowingly , and at every word he clanked the',
#     'target': [52, 57],
#     'highest_similarity': 0.34154475270009294,
#     'corpus_id': 'ccoha1'}]},
#  'facility': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'facility',
#     'sentence': 'facility with which he made his calculations , especially in fractions .',
#     'target': [0, 8],
#     'highest_similarity': 0.34258060045776406,
#     'corpus_id': 'ccoha1'}]},
#  'cleave': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'cleave',
#     'sentence': "He turn 'd in apathy to gaze Upon his Austrian bride , Nor heard dark fate 's prophetic sigh That warn 'd the fall of pride , Saw not the vision 'd battle shock That cleft his Babel fame , Nor mark 'd on far Helena 's rock A sepulchre of shame .",
#     'target': [166, 172],
#     'highest_similarity': 0.3438736276017452,
#     'corpus_id': 'ccoha1'}]},
#  'woman': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'woman',
#     'sentence': 'Forgive me , my good woman , I should not have spoken of this , had I known how near to your heart it was to you .',
#     'target': [21, 26],
#     'highest_similarity': 0.3443119903798011,
#     'corpus_id': 'ccoha1'}]},
#  'thereof': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'thereof',
#     'sentence': 'Coke says , The court of the county is no court of record , 19 and the suitors are the judges thereof .',
#     'target': [94, 101],
#     'highest_similarity': 0.3451749137221944,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'thereof',
#     'sentence': 'But it is time I should introduce you to my friend Mr. Harrington , the present proprietor of the Rookery , together with all the spirits , black and white , red and grey , who are the inhabitants thereof .',
#     'target': [197, 204],
#     'highest_similarity': 0.3452068655675559,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'thereof',
#     'sentence': 'u And the states never , in fact , did in their political capacity , as contradistinguished from the people thereof , ratify the constitution .',
#     'target': [108, 115],
#     'highest_similarity': 0.34675874848008004,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'thereof',
#     'sentence': "Religious Freedom , Under the 6rst amendment of the constitution , congress is prohibited from making any law respecting an establishment of religion , or prohibiting the free exercise thereof . '",
#     'target': [185, 192],
#     'highest_similarity': 0.3977704339818325,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'thereof',
#     'sentence': 'term of every court of sessions , and the Finance Cornruittee of each village and town society , shall , by resolution , determine the amount to be contributed by such society to the funds of the county society , if the same should be required , and notify the president thereof .',
#     'target': [271, 278],
#     'highest_similarity': 0.4054411902760889,
#     'corpus_id': 'ccoha1'}]},
#  'justify': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'justify',
#     'sentence': 'We are as q much said to be sancUfied in Christ Jesus , as to be justified by his merits and obedience .',
#     'target': [65, 72],
#     'highest_similarity': 0.3519576121164437,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'justify',
#     'sentence': 'z We conclude , saith the Apostle , that a man is justified by faithj without the deeds of the law .',
#     'target': [50, 57],
#     'highest_similarity': 0.37342358602746584,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'justify',
#     'sentence': 'our schoolmaster to bring us unto Christ , that we miiht be justified by faith .',
#     'target': [60, 67],
#     'highest_similarity': 0.37682525615120516,
#     'corpus_id': 'ccoha1'}]},
#  'furnish': {'samples': 4,
#   'unassigned_usages': [{'lemma': 'furnish',
#     'sentence': 'The class of 1841 furnished twentysix , and that of 1842 thirtynine , supernumerary lieutenants , or that number more than the service required when they graduated .',
#     'target': [18, 25],
#     'highest_similarity': 0.3529485775337958,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'furnish',
#     'sentence': 'Why he hath arrows enow in his legs to furnish Robin Hood .',
#     'target': [39, 46],
#     'highest_similarity': 0.3772748506902225,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'furnish',
#     'sentence': 'wherewith he had been furnished felt in no talking humor , and sulkily followed the jailer into the house , where he recovered his speech , and recounted his portion of the adventures of the night .',
#     'target': [22, 29],
#     'highest_similarity': 0.38449360963092766,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'furnish',
#     'sentence': 'But there may be other circumstances , in the absence of positive proof , to furnish grounds for believing that',
#     'target': [77, 84],
#     'highest_similarity': 0.40417663927830627,
#     'corpus_id': 'ccoha1'}]},
#  'determine': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'determine',
#     'sentence': 'Both men and horses were so much exhausted by the constant labour they had undergone , that I determined to halt , in order to restore our baggage to some order .',
#     'target': [94, 103],
#     'highest_similarity': 0.354372820703097,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'determine',
#     'sentence': 'The grass being pretty good , although old , we determined to halt for the evening , as the horses were not all arrived having had a considerable detour to make in crossing Allan Water .',
#     'target': [48, 57],
#     'highest_similarity': 0.3956321525641942,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'determine',
#     'sentence': 'most grossly deceived by outward appearances , I determined to be on my guard for the future , and take nothing upon trust .',
#     'target': [49, 58],
#     'highest_similarity': 0.39868273236892926,
#     'corpus_id': 'ccoha1'}]},
#  'gravely': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'gravely',
#     'sentence': 'It is not the splendor with which he has surrounded me , I answered , gravely , but the love which is my earthly Providence , which constitutes my felicity .',
#     'target': [70, 77],
#     'highest_similarity': 0.3549406672448322,
#     'corpus_id': 'ccoha1'}]},
#  'blacken': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'blacken',
#     'sentence': 'and especially ministers , leave a church from base motives , they of course and proverbially hate their former friends , depreciate their talents , and blacken their names .',
#     'target': [153, 160],
#     'highest_similarity': 0.3571350739396323,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'blacken',
#     'sentence': 'You seem to intend a eulogy , yet leave out whatever was noblest in her , and blacken while you mean to praise .',
#     'target': [78, 85],
#     'highest_similarity': 0.3652293626171232,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'blacken',
#     'sentence': 'His apprehensions of the retrihutions of heaven are , day by day , blackening into more substantial realities .',
#     'target': [67, 74],
#     'highest_similarity': 0.39749588727558827,
#     'corpus_id': 'ccoha1'}]},
#  'notice': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'notice',
#     'sentence': 'With less talent and more cunning , he might have become a very rich man , at short notice but being brought up in an oldfashioned school of morality , he could never learn to dignify swindling by the epithet of smartness , nor consider overreaching his neighbor a fair business transaction .',
#     'target': [84, 90],
#     'highest_similarity': 0.3578190378907088,
#     'corpus_id': 'ccoha1'}]},
#  'inward': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'inward',
#     'sentence': "Beethoven 's music prophesies all this , and struggles after it continually therefore , whosoever hears it , with the inward , as well as the outward ear , feels his soul spread its strong pinions , eager to pass the flaming bounds of time and space , and circle all the infinite .",
#     'target': [118, 124],
#     'highest_similarity': 0.3610853233853086,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'inward',
#     'sentence': 'These are matters in which people like to be duped , notwithstanding their inward consciousness that they are deceived .',
#     'target': [75, 81],
#     'highest_similarity': 0.379049357163293,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'inward',
#     'sentence': "Such , for example , is that in which he suggests that our Lord 's walking upon the sea may have been a habitual thing , the outward and harmonious expression of an inward state of spiritual exaltation .",
#     'target': [165, 171],
#     'highest_similarity': 0.39560838146412985,
#     'corpus_id': 'ccoha1'}]},
#  'dispose': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'dispose',
#     'sentence': 'zation , growing out of the division n NewYork , which was brought before that body , as the sole tribunal competent to dispose of it , was , in a degree , the result of this disposition on the part of many members to avoid the difficulty of examining and deciding for themselves .',
#     'target': [120, 127],
#     'highest_similarity': 0.36342463656033186,
#     'corpus_id': 'ccoha1'}]},
#  'ruminate': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'ruminate',
#     'sentence': 'Boabdil ruminated on these words he made many wise resolutions , but he was prone always to act from the impulse of the moment , and was unfortunately given',
#     'target': [8, 16],
#     'highest_similarity': 0.3651146421929761,
#     'corpus_id': 'ccoha1'}]},
#  'industry': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'industry',
#     'sentence': 'The indefatigable industry of Lord Brougham has become almost proverbial .',
#     'target': [18, 26],
#     'highest_similarity': 0.36737379076961585,
#     'corpus_id': 'ccoha1'}]},
#  'revolve': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'revolve',
#     'sentence': 'the young maiden , who sees among the youthful band of aspirants one who is the bright particular star round which her pure and trembling hopes revolve .',
#     'target': [144, 151],
#     'highest_similarity': 0.3673746289607324,
#     'corpus_id': 'ccoha1'}]},
#  'death': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'death',
#     'sentence': 'For if it leaves me without being cured , I shall be cold in death when it abates !',
#     'target': [61, 66],
#     'highest_similarity': 0.37004329536513836,
#     'corpus_id': 'ccoha1'}]},
#  'pour': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'pour',
#     'sentence': 'light , though darkness shroud His way , His love pours beauteous hues through all the cloud .',
#     'target': [50, 54],
#     'highest_similarity': 0.37374820068306985,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'pour',
#     'sentence': 'Spiffard had willingly obeyed the summons , glad to be relieved , in some degree , from his own thoughts by change of place and the veteran , leaning on his arm , continued to pour forth his remarks and moralizings with renewed energy , but with increasing abruptness .',
#     'target': [176, 180],
#     'highest_similarity': 0.40694881669766103,
#     'corpus_id': 'ccoha1'}]},
#  'private': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'private',
#     'sentence': 'It is a wellconducted institution , and its pupils are thoroughly instructed by competent officers , who are graduates of northern colleges , as are most of the public and private',
#     'target': [172, 179],
#     'highest_similarity': 0.37907401115800016,
#     'corpus_id': 'ccoha1'}]},
#  'prevail': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'prevail',
#     'sentence': 'He scarcely opened his eyes , and was with difficulty prevailed upon to answer the questions that were put to him .',
#     'target': [54, 61],
#     'highest_similarity': 0.3795028744367355,
#     'corpus_id': 'ccoha1'}]},
#  'attend': {'samples': 4,
#   'unassigned_usages': [{'lemma': 'attend',
#     'sentence': 'It will readily be seen that the difficulties attending the production of the first number of a work so entirely original , will hardly allow of its being a fair specimen .',
#     'target': [46, 52],
#     'highest_similarity': 0.38201495556469495,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'attend',
#     'sentence': 'The same good fortune does not always attend distinguished men who are described in these Memoirs , so that we are bound in justice to read what is said of them with the same degree of allowance we know bow to make here .',
#     'target': [38, 44],
#     'highest_similarity': 0.3981155295527063,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'attend',
#     'sentence': 'and their agreements are to be judged of by the circumstances attending them .',
#     'target': [62, 68],
#     'highest_similarity': 0.3985720799656677,
#     'corpus_id': 'ccoha1'},
#    {'lemma': 'attend',
#     'sentence': 'The Mississippians began to abandon themselves to the pleasures and dissipations which attend suddenly acquired fortunes .',
#     'target': [87, 93],
#     'highest_similarity': 0.406238008279093,
#     'corpus_id': 'ccoha1'}]},
#  'vindication': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'vindication',
#     'sentence': 'Mr. Morris passed through every variety of trial in this respect , without the slightest faltering of resolution , and on no occasion is it recorded of him , that for the purposes of temporary vindication he sacrificed a public benefit , however remote , or swerved from the',
#     'target': [193, 204],
#     'highest_similarity': 0.39034647467992273,
#     'corpus_id': 'ccoha1'}]},
#  'southern': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'southern',
#     'sentence': 'The Hicksite party had a decided majority in Bucks , Abington , and the Southern quarters .',
#     'target': [72, 80],
#     'highest_similarity': 0.39232766790644447,
#     'corpus_id': 'ccoha1'}]},
#  'perform': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'perform',
#     'sentence': 'And now , too , hearing an incredible popping and fizzing of champagne , I discovered at length , that it proceeded from the person who performed the bottle of that delicate drink during dinner .',
#     'target': [136, 143],
#     'highest_similarity': 0.39234009548673193,
#     'corpus_id': 'ccoha1'}]},
#  'consume': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'consume',
#     'sentence': 'There , Fatima , you know the cause of tears , And all the secret sorrow that consumes me !',
#     'target': [78, 85],
#     'highest_similarity': 0.39303220665546096,
#     'corpus_id': 'ccoha1'}]},
#  'flame': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'flame',
#     'sentence': "Behold o'er northern realms afar Extend the kindling flames of war !",
#     'target': [53, 58],
#     'highest_similarity': 0.3952350399649524,
#     'corpus_id': 'ccoha1'}]},
#  'onset': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'onset',
#     'sentence': 'At the beginning of a conversation he always tries to intimidate , but when his first onset is sustained with firmness , he becomes more mild , and ends by conversing agreeably if in good humor .',
#     'target': [86, 91],
#     'highest_similarity': 0.3988727782347471,
#     'corpus_id': 'ccoha1'}]},
#  'begotten': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'begotten',
#     'sentence': 'They were the offspring of terror and treachery , begotten in the palaces of Kings , by traitors to their duty , and falsifiers of their honor , perjurers , whose oaths could not bind , but only tempted .',
#     'target': [50, 58],
#     'highest_similarity': 0.3989543509942064,
#     'corpus_id': 'ccoha1'}]},
#  'diminish': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'diminish',
#     'sentence': 'Violence on one side and obstinacy on the other rendered his efforts of no avail yet still the Earl of Southampton faithfully attended the daily diminishing court of the misguided Charles .',
#     'target': [145, 153],
#     'highest_similarity': 0.4016938389600171,
#     'corpus_id': 'ccoha1'}]},
#  'range': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'range',
#     'sentence': 'A space had been gradually occupied by the dancers sufficiently large to enable them to walk through the figures and a group of girls ranged',
#     'target': [134, 139],
#     'highest_similarity': 0.40296443610972027,
#     'corpus_id': 'ccoha1'}]},
#  'oppress': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'oppress',
#     'sentence': 'These shadows of memory tell , indistinctly , of tall figures that lifted and bore me in silence down down still down till a hideous dizziness oppressed me at the mere idea of the interminableness of the descent .',
#     'target': [143, 150],
#     'highest_similarity': 0.4044677709927758,
#     'corpus_id': 'ccoha1'}]},
#  'invade': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'invade',
#     'sentence': "What took place when she saw her aged father led away , a prisoner what thoughts invaded that father 's mind when the prison bolt grated on his ear , and he found himself shut from all that had been dear to him through life , regard for the feelings of the reader forbids us recounting here .",
#     'target': [81, 87],
#     'highest_similarity': 0.404831434178528,
#     'corpus_id': 'ccoha1'}]},
#  'destroy': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'destroy',
#     'sentence': "One of the first things noticeable in Fourier 's system of association , is that it destroys all",
#     'target': [84, 91],
#     'highest_similarity': 0.40546343028038045,
#     'corpus_id': 'ccoha1'}]}}

# %%
with open(output_file, 'w') as f:
    json.dump(sample, f, indent=4)

# %%
with open("../data_sampling_2/data/annotation_data/sp_f3_150k_unassigned_prediction_sorted_reevaluated[700].json", 'r') as f:
    sample2 = json.load(f)
    print(f"Number of lemmas with samples: {len(sample2)}")
    display(sample2)

    for lemma in sample2:
        if lemma not in sample:
            sample[lemma] = sample2[lemma]
        else:
            sample[lemma]['unassigned_usages'].extend(sample2[lemma]['unassigned_usages'])
            sample[lemma]['samples'] += sample2[lemma]['samples']
# Out:
# Number of lemmas with samples: 82
# {'qualification': {'samples': 15,
#   'unassigned_usages': [{'lemma': 'qualification',
#     'sentence': "Slovan Bratislava's Champions League qualification tie against Faroe Islands side KI Klaksvik has been cancelled after a player from the Slovakian club tested positive for COVID19, European soccer's governing body UEFA said on Saturday.",
#     'target': [37, 50],
#     'highest_similarity': 0.17304900400543594,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'Streichs team is currently eighth in the 18team Bundesliga, two points behind Hoffenheim in the last place for European qualification.',
#     'target': [120, 133],
#     'highest_similarity': 0.18880463888491522,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'But they have fallen away badly, winning only five times in the league in 2020 and they are in real danger of missing out on a Champions League qualification spot.',
#     'target': [144, 157],
#     'highest_similarity': 0.19225179484657748,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'The bid for Aberdeens first Scottish Cup since 1990 and European qualification are the primary concerns for McGeouch as well as getting back to playing regular football after a frustrating time on the sidelines at the Stadium of Light.',
#     'target': [65, 78],
#     'highest_similarity': 0.19446972677204774,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'Egbo, 47, led KF Tirana to their first league title in a decade back in July becoming the first African coach to lead a European team to a league title and qualification to the UEFA Champions League.',
#     'target': [156, 169],
#     'highest_similarity': 0.22200044927043847,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'The top two teams of each group secure direct qualification while six thirdplaced teams will compete in a separate competition to win the remaining four places.',
#     'target': [46, 59],
#     'highest_similarity': 0.22492466338244757,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'However, they were eight points off Champions League qualification when Emery was dismissed and theyre currently five points adrift under Arteta.',
#     'target': [53, 66],
#     'highest_similarity': 0.23245427946856445,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': "The series will see the launch of the ICC Men's Cricket World Cup Super League which will determine qualification for the 2023 World Cup, with the top seven teams automatically booking their spot at the tournament in India.",
#     'target': [100, 113],
#     'highest_similarity': 0.23804367310993488,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'However, even that might not ensure their qualification as three more teams can possibly get to 14 and pip them on NRR.',
#     'target': [42, 55],
#     'highest_similarity': 0.23937531292468345,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'On that premise, we need our best players starting with the Algeria games to secure that qualification in style.',
#     'target': [89, 102],
#     'highest_similarity': 0.24270379220012872,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'For updated information on the ranking system and the qualification status for athletes for Tokyo, logon to httpworldathletics.',
#     'target': [54, 67],
#     'highest_similarity': 0.2867105357270581,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'It leaves it open to its associations to decide on an appropriate format, but it could mean the introduction of minileagues or playoffs featuring teams in the mix for Champions League or Europa League qualification.',
#     'target': [201, 214],
#     'highest_similarity': 0.28784631821758094,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'It was due to secure qualification for Tokyo 2020 for 77 male and female boxers, with 322 taking part.',
#     'target': [21, 34],
#     'highest_similarity': 0.29423653082755163,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'European qualification is still very much on the agenda for Burnley with only two points separating them from seventhplaced Sheffield United, although there may be some fans keen to avoid that.',
#     'target': [9, 22],
#     'highest_similarity': 0.32189700531077886,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'qualification',
#     'sentence': 'He said international sports federations would be submitting revised plans for qualification processes to the IOC next month.',
#     'target': [79, 92],
#     'highest_similarity': 0.325792638223303,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'wage': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'wage',
#     'sentence': 'Davis gained fame as a state legislator by waging a 2013 filibuster against an antiabortion bill, then lost a race for governor the following year.',
#     'target': [43, 47],
#     'highest_similarity': 0.1949448246727702,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wage',
#     'sentence': 'This tragic failure, however, is an inevitable consequence of the national security establishments determination to ignore critical domestic problems for the sake of waging unending but profitable Global Wars on Terror and new Cold Wars.',
#     'target': [166, 170],
#     'highest_similarity': 0.22913233808382802,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wage',
#     'sentence': 'With one day to go before Hamilton enters COVID lockdown, the city reported another big jump in new COVID cases today with 134 new cases reported, and seven deathsthe highest number of daily deaths since the second wage of the pandemic began.',
#     'target': [215, 219],
#     'highest_similarity': 0.3084568342750876,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wage',
#     'sentence': 'Mr. Guo waged his war against the Chinese government from Facebook and Twitter for months, but then suspended his accounts after he posted the personal information of Chinese people online.',
#     'target': [8, 12],
#     'highest_similarity': 0.3193689538480795,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wage',
#     'sentence': 'So for the past 40 years, we have been waging Jihad, war against terrorism, war against inflation, war against corruption Ehtesaab and war for change Tabdeeli.',
#     'target': [39, 43],
#     'highest_similarity': 0.32297436029253984,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'trample': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'trample',
#     'sentence': 'Trump also reversed Obamas policies that trampled on the religious freedom of prolife charities.',
#     'target': [41, 48],
#     'highest_similarity': 0.226907264770045,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'trample',
#     'sentence': 'By potentially sharing the government, the Afghan leaders are brazenly going to trample on the demagogic claims and promises they held out during electoral campaigns when they would speak strongly against repeating the fiascos of 2014.',
#     'target': [80, 87],
#     'highest_similarity': 0.2550095218510836,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'trample',
#     'sentence': 'We believe that the rights of the francophone population in particular have been completely trampled on, said Justine McIntyre, spokesperson for the Ligue daction civique.',
#     'target': [92, 99],
#     'highest_similarity': 0.27257742650740285,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'trample',
#     'sentence': 'He warned that he would no longer fold his arms and watch any group under any guise trample upon the peace of the state.',
#     'target': [84, 91],
#     'highest_similarity': 0.3856730898183248,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'trample',
#     'sentence': 'Not only do they not have any answer for this question, but they also cause harassment and trample on international law, the military official said.',
#     'target': [91, 98],
#     'highest_similarity': 0.40539232932193686,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'instrumental': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'instrumental',
#     'sentence': 'Six years later, she played an instrumental role in persuading the United Nations Convention on International Trade in Endangered Species CITES to adopt landmark legislation to limit the global seahorse trade to sustainable and legal exports.',
#     'target': [31, 43],
#     'highest_similarity': 0.23527005400185966,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'segment': {'samples': 15,
#   'unassigned_usages': [{'lemma': 'segment',
#     'sentence': 'Sony India, known for its premium tag, plans to fortify its presence in the entrylevel television and home audio segments.',
#     'target': [113, 120],
#     'highest_similarity': 0.24104809652385376,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'It launched SeleQtions as a brand and repositioned Ginger in the lean luxe segment with 20 per cent of its portfolio under it.',
#     'target': [75, 82],
#     'highest_similarity': 0.2527111794578356,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'Lypertek will hope to use its reputation as an audiophilefriendly manufacturer to stand out amidst the competition in the budget true wireless segment.',
#     'target': [143, 150],
#     'highest_similarity': 0.2604580770331163,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'Hyundai appears to be among the leaders in the key future mobility segments autonomy, electrification, and fuel cells.',
#     'target': [67, 74],
#     'highest_similarity': 0.2607771596273514,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The pellet consumption has increased by nearly 20 leading to a higher capacity utilisation of this important segment.',
#     'target': [109, 116],
#     'highest_similarity': 0.27278790188470065,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'Airtel is the largest player in Indias enterprise connectivity segment and serves over 2,500 large businesses and over one million medium and small businesses.',
#     'target': [63, 70],
#     'highest_similarity': 0.2770512660038623,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The company is also in the API segment along with with injectables which is the most attractive one in the pharma sector.',
#     'target': [31, 38],
#     'highest_similarity': 0.27899907687218367,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'Huawei is known to be pushing its efforts in connected cars and autonomous driving, seeing the segments as a potential area for growth outside of its existing businesses.',
#     'target': [95, 102],
#     'highest_similarity': 0.2790776209677419,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'I think augmented reality is legitimately one of the most exciting segments in the industry, and I do believe that things like smart glasses are the formfactor of the near future.',
#     'target': [67, 74],
#     'highest_similarity': 0.2808775413954652,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'Although earnings recovery could be slow, we expect RILs fundamentals to remain supported by ongoing strength in the digital division and the gradual improvement in its energy segment.',
#     'target': [176, 183],
#     'highest_similarity': 0.28124586492382514,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The allnew i20 is all set to reestablish benchmarks in the premium hatchback segment with its sleek style, thrilling performance and unmatched new technologies.',
#     'target': [77, 84],
#     'highest_similarity': 0.2817175430047922,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The 40 yoy decline in export revenues was led by 33 yoy decline in the nonauto segment, 52 yoy decline in the MHCV segment and 26 yoy decline in the PV segment.',
#     'target': [79, 86],
#     'highest_similarity': 0.2831969838530863,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The 40 yoy decline in export revenues was led by 33 yoy decline in the nonauto segment, 52 yoy decline in the MHCV segment and 26 yoy decline in the PV segment.',
#     'target': [79, 86],
#     'highest_similarity': 0.2831969838530863,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'The 40 yoy decline in export revenues was led by 33 yoy decline in the nonauto segment, 52 yoy decline in the MHCV segment and 26 yoy decline in the PV segment.',
#     'target': [79, 86],
#     'highest_similarity': 0.2831969838530863,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'segment',
#     'sentence': 'He also said Uber would accelerate growth at its lossmaking food delivery business, Uber Eats, to become the top player in most of its worldwide markets, eventually increasing the segments margins, which are currently a drag on Uber earnings.',
#     'target': [180, 187],
#     'highest_similarity': 0.28488673244045487,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'strongly': {'samples': 4,
#   'unassigned_usages': [{'lemma': 'strongly',
#     'sentence': 'He skipped around the Mildmay course well before picking up strongly to score with plenty left in the tank.',
#     'target': [60, 68],
#     'highest_similarity': 0.24796892881410482,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'strongly',
#     'sentence': 'A powerful human heart was still beating strongly within Naraku.',
#     'target': [41, 49],
#     'highest_similarity': 0.38363808472212285,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'strongly',
#     'sentence': 'As mentioned, stocks rallies strongly today.',
#     'target': [29, 37],
#     'highest_similarity': 0.38888533992561336,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'strongly',
#     'sentence': 'Global trade flows bounced back strongly in the summer, marking the largest rise in two decades as air and sea transport channels reopened while demand for consumer goods surged.',
#     'target': [32, 40],
#     'highest_similarity': 0.39665842259137396,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'fabric': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'fabric',
#     'sentence': 'They are to be woven into the fabric of our lives.',
#     'target': [30, 36],
#     'highest_similarity': 0.2790225350475645,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'fabric',
#     'sentence': 'Notice that Photoshop provides 20 free styles in four categories Basic, Natural, Fur, and Fabric to get you started.',
#     'target': [90, 96],
#     'highest_similarity': 0.3541841718224733,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'basis': {'samples': 13,
#   'unassigned_usages': [{'lemma': 'basis',
#     'sentence': 'The MPC, on Friday, maintained all economic parameters unchanged, except the CRR that was raised by 500 basis point to 27.5 per cent.',
#     'target': [104, 109],
#     'highest_similarity': 0.28073072383949643,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'On the quantum of reduction, the MPC voted with a 51 majority to reduce the policy rate by 40 basis points from 4.4 per cent to 4.0 per cent.',
#     'target': [94, 99],
#     'highest_similarity': 0.2845556581253129,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'We expanded segment margin 150 basis points or 70 basis points, excluding the impact of the 2018 spinoff, both 10 basis points above the high end of our 2019 guidance.',
#     'target': [31, 36],
#     'highest_similarity': 0.2922010228166797,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'We expanded segment margin 150 basis points or 70 basis points, excluding the impact of the 2018 spinoff, both 10 basis points above the high end of our 2019 guidance.',
#     'target': [31, 36],
#     'highest_similarity': 0.2922010228166797,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'We expanded segment margin 150 basis points or 70 basis points, excluding the impact of the 2018 spinoff, both 10 basis points above the high end of our 2019 guidance.',
#     'target': [31, 36],
#     'highest_similarity': 0.2922010228166797,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'Earlier, it was linked to the Reserve Bank of India bank rate plus 300 basis points.',
#     'target': [71, 76],
#     'highest_similarity': 0.3059160646591803,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'The RBI has cut policy rates by 115 basis points since February.',
#     'target': [36, 41],
#     'highest_similarity': 0.31185033482941127,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'Contribution of issuers of debt securities to core SGF shall be equivalent to 0.5 basis points of the issuance value of debt securities per annum based on the maturity of debt securities, to be collected upfront, the regulator said.',
#     'target': [82, 87],
#     'highest_similarity': 0.314034962627852,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'The provision for credit losses on impaired loans ratio was 29 basis points, compared with 12 basis points in the prior year.',
#     'target': [63, 68],
#     'highest_similarity': 0.33910454366640436,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'The provision for credit losses on impaired loans ratio was 29 basis points, compared with 12 basis points in the prior year.',
#     'target': [63, 68],
#     'highest_similarity': 0.33910454366640436,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'Despite energys decreasing weight in the SP 500, excluding it is making a difference this year as SPXE is beating the traditional SP 500 by nearly 200 basis points yeartodate.',
#     'target': [151, 156],
#     'highest_similarity': 0.3567935278234747,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'Government bonds were firmer in early deals, and the yield on the instrument due in 2030 fell 3.5 basis points to 9.31.',
#     'target': [98, 103],
#     'highest_similarity': 0.3748317471032115,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'basis',
#     'sentence': 'Stolen bases are a thing for me, Betts said.',
#     'target': [7, 12],
#     'highest_similarity': 0.4003242570273943,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'despite': {'samples': 7,
#   'unassigned_usages': [{'lemma': 'despite',
#     'sentence': 'Castro finished with 27 points, five rebounds and eight assists for the Tropang Giga who still lead standings despite the defeat.',
#     'target': [110, 117],
#     'highest_similarity': 0.29408762338173233,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': 'The 37yearold actress also revealed the one rule thatand she had been following to make their marriage work despite being extremely busy with their schedules.',
#     'target': [108, 115],
#     'highest_similarity': 0.3907908053787283,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': 'Last weeks episode of Raw drew 2.437 million viewers, the best number of 2020 despite an aggressive firsttothird hour decline.',
#     'target': [78, 85],
#     'highest_similarity': 0.3948958184321579,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': 'Abraham is behind on 38.2m despite an impressive haul of 13 goals, midfielder Mount on 33m and rightback Reece James on 23.',
#     'target': [27, 34],
#     'highest_similarity': 0.39609121307488737,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': 'Observers say market conditions remain strong and that indications of solid demand mean growers should continue to see relatively strong prices despite expanding supply and competition from lowercost pistachios from Iran.',
#     'target': [144, 151],
#     'highest_similarity': 0.3966424187289893,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': 'Critics described him as a virtual dictator, but despite its poverty Kenya was more stable than many other countries in the region emerging from colonial rule.',
#     'target': [49, 56],
#     'highest_similarity': 0.4002878013017666,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'despite',
#     'sentence': "The 20yearold has played just 81 minutes of firstteam football this season and did not make the bench for Sunday's Premier League defeat at Leicester despite Willian being out injured.",
#     'target': [150, 157],
#     'highest_similarity': 0.4013195586867892,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'wipe': {'samples': 6,
#   'unassigned_usages': [{'lemma': 'wipe',
#     'sentence': 'Her path to victory would need to see her dominate in her strongest areas Saskatchewan, Alberta and parts of Ontario and Atlantic Canada and not be totally wiped out in Quebec.',
#     'target': [156, 160],
#     'highest_similarity': 0.30219977111794577,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wipe',
#     'sentence': 'Beneath Mount Rushmore on the eve of Independence Day, President Trump addressed his holiday remarks to his narrow base of angry white voters while charging that advocates of racial justice are promoting a merciless campaign to wipe out our history.',
#     'target': [228, 232],
#     'highest_similarity': 0.34968503013017666,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wipe',
#     'sentence': 'Okay, to be fair, there is probably no way it is going to be as bad as that show was to sit through, but WWE is slowly wiping any goodwill I have towards professional wrestling away with whatever the hell it is they think theyre doing.',
#     'target': [119, 123],
#     'highest_similarity': 0.3582646314641299,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wipe',
#     'sentence': 'Researchers arrived with their own hopes and hypotheses, which the truth often wiped out.',
#     'target': [79, 83],
#     'highest_similarity': 0.35892125920892637,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wipe',
#     'sentence': 'Technology companies, whose supply chains have been disrupted, accounted for much of the broad market slide, which wiped out all of the Dows and SP 500s gains for the year.',
#     'target': [115, 119],
#     'highest_similarity': 0.38760121995923036,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wipe',
#     'sentence': 'Notably, the local Native American tribes were not targeted or wiped the new nation embraced them as equals and allowed the tribes a major say in the rule of America.',
#     'target': [63, 67],
#     'highest_similarity': 0.39197082200844,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'roughly': {'samples': 9,
#   'unassigned_usages': [{'lemma': 'roughly',
#     'sentence': 'As part of the legal fight, thenViacom CEO Philippe Dauman accused Herzer who was roughly 40 years younger than Redstone of being concerned only with his money.',
#     'target': [82, 89],
#     'highest_similarity': 0.30390490889421357,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': "The job cuts affect roughly 3 per cent of Dixons' total workforce in the UK and Ireland.",
#     'target': [20, 27],
#     'highest_similarity': 0.3291543880981332,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': 'A spokeswoman said the regulator had expected to get roughly 1100 applications this year but had received approximately 2000.',
#     'target': [53, 60],
#     'highest_similarity': 0.3512409028324154,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': 'In 2018, a case of the first in Indonesia since 2006 emerged in Papua, while a killed roughly 100 children.',
#     'target': [86, 93],
#     'highest_similarity': 0.36597892899291895,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': 'Narrating his ordeal, the Lion King from Maposa village, roughly 10km from Nata, revealed he set off with two friends at around 7pm on 19 September after kraaling their cattle.',
#     'target': [57, 64],
#     'highest_similarity': 0.36649989271153705,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': 'The lake, covering roughly 300 square metres 3,229 square feet, is connected to the Maoyan River through underground streams.',
#     'target': [19, 26],
#     'highest_similarity': 0.3771907298297689,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': "We're making copies and deliveries to get them covered, but this Caucus is gonna be the big one, he tweeted roughly 20 minutes before the caucuses began.",
#     'target': [108, 115],
#     'highest_similarity': 0.38246180083684994,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': 'Asked how he can say the pandemic is under control when roughly 1,000 Americans are dying from Covid19 each day, Trump said, remarkably, that it is what it is.',
#     'target': [56, 63],
#     'highest_similarity': 0.3886847775552535,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'roughly',
#     'sentence': "John Vansice's friend, LaDonna Woodford, says roughly 2 years after Jodi's disappearance, she received a visit from an FBI agent.",
#     'target': [46, 53],
#     'highest_similarity': 0.3957633797653959,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'warmly': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'warmly',
#     'sentence': 'Recent rainfall in Argentina were warmly welcomed by local farmers and depleted soil moisture conditions alike.',
#     'target': [34, 40],
#     'highest_similarity': 0.30537225743866675,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'relegate': {'samples': 7,
#   'unassigned_usages': [{'lemma': 'relegate',
#     'sentence': 'After missing out on a Uefa Cup place despite their highestever league finish, Palace were relegated at the end of the Premier Leagues inaugural season in 199293 as Coppells exciting side broke up following the sale of Wright to Arsenal.',
#     'target': [91, 99],
#     'highest_similarity': 0.30687451943709315,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'But a chance to return to his first club where he played in the topflight between 2002 and 2004, when they were relegated could be too enticing to turn down.',
#     'target': [112, 120],
#     'highest_similarity': 0.3240490218868464,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'But a chance to return to his first club where he played in the topflight between 2002 and 2004, when they were relegated could be too enticing to turn down.',
#     'target': [112, 120],
#     'highest_similarity': 0.3240490218868464,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'Kanyenda, who facilitated Muyaba and defender Dennis Chembezis moves to the relegated South African club, said he will in future think twice before helping Malawian players.',
#     'target': [76, 84],
#     'highest_similarity': 0.32977797993705743,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'Theres no need to have more time off, go straight into the next season with the teams that should be relegated and the teams that should be promoted.',
#     'target': [101, 109],
#     'highest_similarity': 0.3520113792825978,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'The Saints are almost 93 million over the projected 2021 salary cap, the team may have to be relegated to a sevenonseven league to make ends meet.',
#     'target': [93, 101],
#     'highest_similarity': 0.3587852152027752,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'relegate',
#     'sentence': 'Manchester City are on the verge of signing Dutch centre back Nathan Ake from relegated side Bournemouth after the Cherries accepted 41 million from the Premier League giants.',
#     'target': [78, 86],
#     'highest_similarity': 0.38324761059652385,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'installation': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'installation',
#     'sentence': 'As previously stated in multiple letters from the installation to MDOT, the Navy will not cede any property for the construction of this toll road, Seymour writes.',
#     'target': [50, 62],
#     'highest_similarity': 0.3142489472319576,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'haul': {'samples': 8,
#   'unassigned_usages': [{'lemma': 'haul',
#     'sentence': 'Cornyn has not yet revealed his haul for the period, but he has said she outraised him for the period and basically wiped out the large cashonhand advantage he has had since the beginning of the cycle.',
#     'target': [32, 36],
#     'highest_similarity': 0.31876964250246326,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'I must confess that before the question was, for the umpteenth time, put to me, that theyve already being in the social media space hauling over the coals on him to the extent that some called him Fake Pastor.',
#     'target': [132, 136],
#     'highest_similarity': 0.36201908606439953,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': "Nadal has now tied Roger Federer's haul of 20 majors with Djokovic, the last active player to beat the Spaniard at Roland Garros, three adrift.",
#     'target': [35, 39],
#     'highest_similarity': 0.3671701215041842,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'But somehow, for over 40 years, they held it together, like a pair of bickering partners who fight bitterly but are still in it for the long haul.',
#     'target': [141, 145],
#     'highest_similarity': 0.37030440866175524,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'Wahab Riaz, also a leftarm fast bowler like Shaheen, moved up six places to 60th position, grabbing five wickets in two matches, including a haul of 441 in the second match of the series.',
#     'target': [141, 145],
#     'highest_similarity': 0.3755009096483087,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'The quickfire goals were harsh on Getafe but the visitors hauled themselves back into contention through top scorer Rodriguez, who has been linked with a move to Barca as an emergency replacement for the injured Ousmane Dembele.',
#     'target': [58, 62],
#     'highest_similarity': 0.39014566194228345,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'We are in this for the long haul and it isnt soldiers on the frontline, its our brave doctors, nurses, NHS staff, support workers and carers.',
#     'target': [28, 32],
#     'highest_similarity': 0.4003695416994492,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'haul',
#     'sentence': 'We lock away what we dont want to confront, says the actor Hill Harper in his narration for The Prison Within, describing a system that is easier in the short term, but destructive in the long haul.',
#     'target': [193, 197],
#     'highest_similarity': 0.40233775972748725,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'fashioned': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'fashioned',
#     'sentence': 'Starmer was the favorite to succeed Corbyn from the start, as Labour members apparently decided they needed to put their hopes of winning ahead of any emotioal attachment to the former leaders old fashioned leftwing ideals.',
#     'target': [197, 206],
#     'highest_similarity': 0.3199245851512767,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'fashioned',
#     'sentence': "When Peggy receives a need improvement evaluation during a surprise inclass visit, she takes it out on her unruly students by giving one of them a good ol' fashioned spanking.",
#     'target': [156, 165],
#     'highest_similarity': 0.3971554810993491,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'property': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'property',
#     'sentence': 'Named pages with pageorientation Support is added for several CSS properties and descriptors for printing.',
#     'target': [66, 74],
#     'highest_similarity': 0.31998371674057646,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'impair': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'impair',
#     'sentence': 'Guinness Nigeria carried out a comprehensive review of its asset base and made a strategic decision to impair a certain category of assets, which were generating suboptimal returns.',
#     'target': [103, 109],
#     'highest_similarity': 0.3239470419676703,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'flex': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'flex',
#     'sentence': 'The service from the Comcastowned company will launch on April 15 for Comcasts X1 and Flex customers and will debut nationally three months later on July 15, NBCUniversal announced at its media event for the service on Thursday.',
#     'target': [86, 90],
#     'highest_similarity': 0.32711390681996994,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'veer': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'veer',
#     'sentence': 'Halloran, the Spokane epidemiologist, said she has taken to wondering how it all veered so off track.',
#     'target': [81, 85],
#     'highest_similarity': 0.3275657253594163,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'veer',
#     'sentence': 'Theyd also have to change around their entire offense and veer away from young QB Jarrett Stidham to sign the veteran.',
#     'target': [58, 62],
#     'highest_similarity': 0.3348851454652743,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'veer',
#     'sentence': 'The charges are the same as last time gullible Americans being brainwashed against the Democratic establishment but the evidence presented veers off into parody.',
#     'target': [139, 143],
#     'highest_similarity': 0.3870187777161862,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'navigate': {'samples': 12,
#   'unassigned_usages': [{'lemma': 'navigate',
#     'sentence': 'The UNRC, Ms. Nathalie Fustier added Cooperation with ICD on such a crucial issue will be instrumental in finding innovative ways to navigate these uncertain times.',
#     'target': [133, 141],
#     'highest_similarity': 0.3295417441527787,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'With the pandemic adding to pressure on a number of African countries already struggling with unsustainable debt, Zambia is being closely watched as a test case for how borrowers and creditors might navigate a broader debt crisis.',
#     'target': [199, 207],
#     'highest_similarity': 0.330968188970746,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'There are not enough resources for Latino communities, Gonzalez said, pointing out that her parents were asking her for help navigating early voting.',
#     'target': [125, 133],
#     'highest_similarity': 0.3577810063657821,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'With purposeful planning, Perrette has experienced meaningful longterm assignments within both realms of his existence, and has expertly navigated the desire for professional, and personal fulfillment.',
#     'target': [137, 145],
#     'highest_similarity': 0.35855965238538007,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'And a big country with 200 million people presently, our role in this country is truly a fantastic achievement to be able to navigate for 60 years, without major conflict with any country in the world.',
#     'target': [125, 133],
#     'highest_similarity': 0.36036761944782203,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'Looking ahead, the company is confident that its capabilities, balanced portfolio, strong client relationships and financial strength will help navigate this ongoing crisis and emerge stronger, he added.',
#     'target': [144, 152],
#     'highest_similarity': 0.3709690271618625,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'The show delved deeply into serious issues as the characters tried their best to navigate a difficult and ethically ambiguous business.',
#     'target': [81, 89],
#     'highest_similarity': 0.38084082862456187,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'We take our commitment to student success and wellbeing seriously and that commitment guides our decisions as we continue to navigate this difficult situation.',
#     'target': [125, 133],
#     'highest_similarity': 0.38400105500321857,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'I am incredibly proud of the education leaders who have been navigating this extraordinary situation for weeks.',
#     'target': [61, 69],
#     'highest_similarity': 0.3844617695443816,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'Thats why today as we continue our exclusive WW series to help you navigate the challenges of the coronavirus lockdown without piling on the pounds were sharing brilliant WW recipes for muffins, cakes and other sweet treats for you to try at home.',
#     'target': [67, 75],
#     'highest_similarity': 0.4029789982833845,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'How have you and your team navigated the crisis?',
#     'target': [27, 35],
#     'highest_similarity': 0.4056335942529147,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'navigate',
#     'sentence': 'Or it can be sharing strategies and ways they can navigate the world.',
#     'target': [50, 58],
#     'highest_similarity': 0.4060349983906731,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'baked': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'baked',
#     'sentence': 'No wonder hes up there getting big baked.',
#     'target': [35, 40],
#     'highest_similarity': 0.3308091450003576,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'heartbeat': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'heartbeat',
#     'sentence': 'The post of vice president is described as heartbeat away from the presidency and she is the first nonWhite candidate for the job and the third woman from a major party.',
#     'target': [43, 52],
#     'highest_similarity': 0.3318605384092697,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'different': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'different',
#     'sentence': 'Should city or county officials require it, Malone is prepared to further reduce the number of teams, or break up the teams into flights that will launch and weigh in their catches at different times.',
#     'target': [184, 193],
#     'highest_similarity': 0.33746361132966163,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'different',
#     'sentence': 'PD is enhanced with remote systems that collect medical health data from individuals after completion of the therapy and electronically transmit them to a doctor at a different location for assessment and recommendations.',
#     'target': [167, 176],
#     'highest_similarity': 0.3558384928653172,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'different',
#     'sentence': 'By examining the differences in the surface elevation of glaciers at different points in time, we were able to measure how quickly glaciers across the region have thinned over the past five decades.',
#     'target': [69, 78],
#     'highest_similarity': 0.4052366939954223,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'unit': {'samples': 10,
#   'unassigned_usages': [{'lemma': 'unit',
#     'sentence': 'Fifteen of those patients on the unit have shown symptoms of COVID19.',
#     'target': [33, 37],
#     'highest_similarity': 0.34219027161862525,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'According to reports, the TV star was brutally beaten by her LHH Atlanta costars to the point she had to be treated in a hospital intensive care unit.',
#     'target': [145, 149],
#     'highest_similarity': 0.35709826058579497,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'As Utah continues to report new coronavirus cases at unprecedented levels, a second Utah hospital has filled its intensive care unit, forcing it to open and staff overflow beds.',
#     'target': [128, 132],
#     'highest_similarity': 0.3576493880087261,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'There are currently 325 people hospitalized with COVID19, with 48 patients in intensive care units and 25 people intubated all down from the day prior.',
#     'target': [93, 97],
#     'highest_similarity': 0.3580125929833345,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'A number of crew members onboard the Ruby Princess have been evacuated from the ship and taken to hospital in Sydney in recent days, some needing treatment in intensive care units.',
#     'target': [174, 178],
#     'highest_similarity': 0.3662064587654674,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'CBS affiliate KREMTV said Wednesday that the hospital is among 10 in the country with a specialized unit.',
#     'target': [100, 104],
#     'highest_similarity': 0.36701606197696873,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'Brooks is currently undergoing treatment for COVID19 and double pneumonia in TennovaClevelands medical intensive care unit.',
#     'target': [118, 122],
#     'highest_similarity': 0.3809274528824833,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'In L.A. County, there were 1,783 people hospitalized as of Tuesday, with 26 in intensive care units and 18 on ventilators.',
#     'target': [94, 98],
#     'highest_similarity': 0.38903758896001717,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'When we get these patients that should be in the ICU in our unit, we tend to send them back in a couple of days, she said.',
#     'target': [60, 64],
#     'highest_similarity': 0.39968952283456116,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'unit',
#     'sentence': 'Kaieteur News understands that due to the influx of injured bikers in the male surgical ward of the city hospital, there is now a shortage of beds in the unit.',
#     'target': [154, 158],
#     'highest_similarity': 0.4047352210142336,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'include': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'include',
#     'sentence': 'Adverts that attempt to describe different races as a threat will be banned and content that could incite violence or suppress voting including from politicians will also be banned.',
#     'target': [134, 141],
#     'highest_similarity': 0.3457971532794506,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'include',
#     'sentence': 'Were now in a situation where an underresourced hospital is being asked to manage the epicenter of the crisis, said Zellnor Myrie, a Democratic state senator whose district includes University Hospital.',
#     'target': [173, 180],
#     'highest_similarity': 0.3734298556970173,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'include',
#     'sentence': "Lodi Chamber of Commerce president and CEO Pat Patrick signed a letter to Governor Gavin Newsom, according to Associated Press AP, to lobby against Newsom's recent safety orders including shutdowns of some business sectors.",
#     'target': [178, 185],
#     'highest_similarity': 0.3939272606573207,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'stuff': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'stuff',
#     'sentence': 'Everybody does stuff different at home and you get to learn about that by going to school with all these different people.',
#     'target': [15, 20],
#     'highest_similarity': 0.34850081136900074,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'wide': {'samples': 5,
#   'unassigned_usages': [{'lemma': 'wide',
#     'sentence': 'Three made the Rams roster Running back Xavier Jones, wide receiver Trishton Jackson and defensive lineman Eric Banks.',
#     'target': [54, 58],
#     'highest_similarity': 0.34938000679493597,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wide',
#     'sentence': 'The Broncos were forced to call up Kendall Hinton, an undrafted rookie wide receiver who had played quarterback at Wake Forest, from the practice squad to play a key position against the New Orleans Saints with 24 hours notice.',
#     'target': [71, 75],
#     'highest_similarity': 0.353783617051713,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wide',
#     'sentence': 'For the Jets, their biggest impending free agent is wide receiver Robby Anderson.',
#     'target': [52, 56],
#     'highest_similarity': 0.38261767085687715,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wide',
#     'sentence': 'On day two, in the second round the Eagles had the chance to draft another wide receiver or fill a need at cornerback or linebacker.',
#     'target': [75, 79],
#     'highest_similarity': 0.3913697830984908,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'wide',
#     'sentence': 'But Houston did acquire versatile running back David Johnson, who is a multidimensional threat when healthy, and added veteran wide receivers Brandin Cooks and Randall Cobb to a group that already included Will Fuller and Kenny Stills.',
#     'target': [127, 131],
#     'highest_similarity': 0.40042048136757025,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'startup': {'samples': 8,
#   'unassigned_usages': [{'lemma': 'startup',
#     'sentence': 'The latest funding round also is also backed by US venture capital firm Point72 Ventures, local investment fund Acorn Capital and prominent local investor David Fite and brings the total raised by the startup to 51.5 million.',
#     'target': [201, 208],
#     'highest_similarity': 0.3499673664258636,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
#     'sentence': 'Startup Boost delivers a powerful sixweek programme to prepare earlystage startups for an accelerator and investment, providing a critical bridge to their next level growth.',
#     'target': [74, 81],
#     'highest_similarity': 0.3552396444281525,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
#     'sentence': 'Badnore said can become a model startup hub, inspiring other cities by incorporating requisite policy changes and by leveraging its existing institutions of national importance and facilitating the industry and academic interface.',
#     'target': [32, 39],
#     'highest_similarity': 0.3614823689292611,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
#     'sentence': 'With the fresh capital, the startup plans to invest in product capabilities and expand its sales and marketing efforts worldwide.',
#     'target': [28, 35],
#     'highest_similarity': 0.3719596684786496,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
#     'sentence': 'Technology investors and startups will go where they can function most efficiently in technology terms this translates to the fastest internet services.',
#     'target': [25, 32],
#     'highest_similarity': 0.38398641459838345,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
#     'sentence': 'Back in 2017, Honeywell had launched a new investment fund to invest in earlystage startups that are strategically aligned to the companys portfolio and software capabilities, it had said in a statement.',
#     'target': [83, 90],
#     'highest_similarity': 0.39406156122594943,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'startup',
# ...
#     'highest_similarity': 0.374585318914956,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'notice': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'notice',
#     'sentence': "The zoo said it expects the supply of the panda's main food could be further disrupted by transportation struggles on very short notice, including if there is a second wave of COVID19.",
#     'target': [129, 135],
#     'highest_similarity': 0.3755270881017094,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'threat': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'threat',
#     'sentence': 'In 2015, Brock Lesnar beat John Cena and Seth Rollins in a triple threat match.',
#     'target': [66, 72],
#     'highest_similarity': 0.37612343314140617,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'status': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'status',
#     'sentence': 'In fact, press imagery for the New Facebook still shows a stream of status updates.',
#     'target': [68, 74],
#     'highest_similarity': 0.3772857471747371,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'warning': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'warning',
#     'sentence': 'This allows the vehicle to trigger a warning or an emergency braking maneuver as required.',
#     'target': [37, 44],
#     'highest_similarity': 0.37795633359559394,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'invisible': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'invisible',
#     'sentence': 'After years of being silenced, the achievements of women are rendered invisible by the phrase a woman .',
#     'target': [70, 79],
#     'highest_similarity': 0.3784547108575924,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'invisible',
#     'sentence': 'I pledged to never take for granted the invisible people and to treat them with kindness and respect.',
#     'target': [40, 49],
#     'highest_similarity': 0.38308114584078384,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'revolve': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'revolve',
#     'sentence': "The central thrust of his lawyers' extradition challenge, however, revolves around the argument that to criminalise Assange would make it unlawful for news outlets to publish stories based on leaked government documents.",
#     'target': [67, 74],
#     'highest_similarity': 0.37927640743262175,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'revolve',
#     'sentence': 'Im at that age where many of my friends are having children, and a central topic of conversation whenever were together revolves around creating the almostscientifically set schedule for their babies.',
#     'target': [120, 127],
#     'highest_similarity': 0.3911762950611543,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'revolve',
#     'sentence': 'My campaign revolves around the image of the first day that the sun comes up over South Carolina and our country and Donald Trump is no longer the president of the United States, Mr. Buttigieg said at the Columbia Urban Leagues annual King breakfast.',
#     'target': [12, 19],
#     'highest_similarity': 0.3948552499821186,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'facility': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'facility',
#     'sentence': 'In pursuit of these and other objectives, the GEMXIM Bank CEO said his outfit signed a US100 million facility in the UK in January this year.',
#     'target': [101, 109],
#     'highest_similarity': 0.3792878840032901,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'religiously': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'religiously',
#     'sentence': 'Track and field athletics have grown to become a national pastime, followed and supported religiously by all Jamaicans.',
#     'target': [90, 101],
#     'highest_similarity': 0.38012276253297655,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'logical': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'logical',
#     'sentence': 'To be precise, any data we store in the hard drive is susceptible to the fragile nature of these drives, not so secure environment of the internet our system depends on and vulnerability of the internal system to logical and mechanical failures.',
#     'target': [213, 220],
#     'highest_similarity': 0.3816683691259566,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'embed': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'embed',
#     'sentence': 'You can watch s performance at the 2500 mark in the Vimeo embed.',
#     'target': [58, 63],
#     'highest_similarity': 0.3818690544310135,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'pipeline': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'pipeline',
#     'sentence': 'Theres always a lot in the pipeline for Jessica Chastain.',
#     'target': [27, 35],
#     'highest_similarity': 0.3825485368535869,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'pipeline',
#     'sentence': 'There should be some things that can be done in the short term, but in terms of developing the pipeline further on coaching and executive positions, that would take a longer period of time.',
#     'target': [95, 103],
#     'highest_similarity': 0.39994606519562254,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'pipeline',
#     'sentence': 'The Company is also progressing a robust pipeline of investigational therapies targeting areas of serious unmet need, including neutrophilmediated inflammatory diseases and rare pulmonary disorders.',
#     'target': [41, 49],
#     'highest_similarity': 0.40353154504327304,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'downward': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'downward',
#     'sentence': 'Chinese health authorities say two new coronavirus cases were confirmed Saturday, continuing a downward trend since the government took steps to cut the number of people arriving from overseas.',
#     'target': [95, 103],
#     'highest_similarity': 0.3828719892175095,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'perform': {'samples': 3,
#   'unassigned_usages': [{'lemma': 'perform',
#     'sentence': 'Northland Securities upgraded shares of Intel from an under perform rating to a market perform rating and set a 46.00 price target for the company in a research note on Monday, November 2nd.',
#     'target': [60, 67],
#     'highest_similarity': 0.38398935385523203,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'perform',
#     'sentence': 'Northland Securities upgraded shares of Intel from an under perform rating to a market perform rating and set a 46.00 price target for the company in a research note on Monday, November 2nd.',
#     'target': [60, 67],
#     'highest_similarity': 0.38398935385523203,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'perform',
#     'sentence': 'Having spent a couple of months with the MagniFi Mini from Polk Audio, lets look at how it performs.',
#     'target': [91, 98],
#     'highest_similarity': 0.3843893386560332,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'course': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'course',
#     'sentence': 'Basically what we did at the beginning of COVID19, Kern said, was challenge faculty to take their learning objectives for the course and think creatively as to how they can be met in a remote teaching scenario.',
#     'target': [126, 132],
#     'highest_similarity': 0.3853947656641155,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'hardly': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'hardly',
#     'sentence': 'Baldwin was hardly nave about the human capacity for evil, especially in white folk.',
#     'target': [12, 18],
#     'highest_similarity': 0.3854920740648021,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'handle': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'handle',
#     'sentence': 'From sharing his opinions, taking digs at contestants and giving an insiders take on the happenings, Vindus Twitter handle is quite active every season.',
#     'target': [116, 122],
#     'highest_similarity': 0.3865570238180387,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'claim': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'claim',
#     'sentence': 'The No. 4 singles match was the next on the board, as PaladiniJennings picked up her eighth win of the spring to put the Governors a point away from claiming the match.',
#     'target': [149, 154],
#     'highest_similarity': 0.3866215421822473,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'claim',
#     'sentence': 'Adding one additional centimeter to his indoor record height would have allowed Fisher to claim the outdoor record, cementing his name in Middleburys athletic history.',
#     'target': [90, 95],
#     'highest_similarity': 0.3940601530648737,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'deeply': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'deeply',
#     'sentence': 'Dollar General is deeply involved in the communities it serves and is an ardent supporter of literacy and education.',
#     'target': [18, 24],
#     'highest_similarity': 0.3866958617945784,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'awaken': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'awaken',
#     'sentence': 'We can love it, not simply use it, with the result that love can awaken a deep and sincere interest.',
#     'target': [65, 71],
#     'highest_similarity': 0.38924430924111286,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'like': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'like',
#     'sentence': 'The MLB and the MLBPA have yet to come to an agreement to start the season due to a dispute over salaries but it looks like they may have another hurdle to clear when it comes to the Coronavirus.',
#     'target': [119, 123],
#     'highest_similarity': 0.3896675510514269,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'like',
#     'sentence': 'Getyourgreyon was luckless last time out and for a good while yesterday it looked like he might meet a similar fate again, but a midrace move by jockey Jag GuthmannChester alleviated those concerns and he proved a mile too good.',
#     'target': [82, 86],
#     'highest_similarity': 0.40098314230026455,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'unmarked': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'unmarked',
#     'sentence': 'Mooy delivers another ball into the box towards the unmarked Belgian.',
#     'target': [52, 60],
#     'highest_similarity': 0.3899959990344038,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'immediate': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'immediate',
#     'sentence': 'His actions directly violated the law as California law prohibits referrals where the physician or his immediate family has a financial interest with the person or entity receiving the referral.',
#     'target': [103, 112],
#     'highest_similarity': 0.391126942368214,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'civic': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'civic',
#     'sentence': "The Ottawa Hospital's Civic campus in April 2020, the month that saw the highest number of patients being treated for COVID19.",
#     'target': [22, 27],
#     'highest_similarity': 0.3911992167942207,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'national': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'national',
#     'sentence': 'Minnesota Vikings quarterback Kirk Cousins says that the league is waking up to what Colin Kaepernick was attempting to say when, some seasons back, he started taking a knee during the national.',
#     'target': [185, 193],
#     'highest_similarity': 0.394068356161934,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'national',
#     'sentence': "He added that final year students will not sit for this year's national examinations.",
#     'target': [63, 71],
#     'highest_similarity': 0.40563938335955935,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'seize': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'seize',
#     'sentence': 'All that said, it shouldnt come as a surprise that Newton has seized control of the Patriots starting quarterback job.',
#     'target': [62, 67],
#     'highest_similarity': 0.39413925595450966,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'procedural': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'procedural',
#     'sentence': 'As the White House Coronavirus Task Force gave its update Sunday night, the Senate failed to pass a procedural vote to move forward with an economic stimulus bill that could cost between 1.5 and 2 trillion.',
#     'target': [100, 110],
#     'highest_similarity': 0.3965867516629712,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'internal': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'internal',
#     'sentence': 'This transaction allows us to take advantage of the strong gold price environment at a forward price that is significantly higher than our internal gold price forecasts used for reserve calculations and budgeting.',
#     'target': [139, 147],
#     'highest_similarity': 0.3974727755525355,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'chokehold': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'chokehold',
#     'sentence': 'MILAN The coronavirus has a chokehold on the global economy.',
#     'target': [28, 37],
#     'highest_similarity': 0.3981461224161362,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'textile': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'textile',
#     'sentence': 'Whichever title fits you best, you are an musician waiting to produce your most current masterpiece with particular textile, shades of thread and also distinct styles.',
#     'target': [116, 123],
#     'highest_similarity': 0.40139933212931833,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'virtually': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'virtually',
#     'sentence': 'It will take time to adjust to all that is needed from building routines, learning inperson or virtually, teaching in both venues simultaneously, and striving to be together when we are physically apart.',
#     'target': [95, 104],
#     'highest_similarity': 0.40192411799942773,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'early': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'early',
#     'sentence': 'But as far as Foles maybe or maybe not being the ultimate solution and who will get a shot at picking the next quarterback, boy, youre a little early with that.',
#     'target': [144, 149],
#     'highest_similarity': 0.40238777179743934,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'living': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'living',
#     'sentence': 'The singlestory east wing has four bedrooms, four and a half baths and a spacious living room.',
#     'target': [82, 88],
#     'highest_similarity': 0.40310986785637654,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'province': {'samples': 2,
#   'unassigned_usages': [{'lemma': 'province',
#     'sentence': 'She explained that the funds are meant for the two districts in Muchinga province as they were hot spots for Covid 19 and most hit by the pandemic in the province.',
#     'target': [73, 81],
#     'highest_similarity': 0.4034035364959587,
#     'corpus_id': 'leipzig_eng_news'},
#    {'lemma': 'province',
#     'sentence': 'She explained that the funds are meant for the two districts in Muchinga province as they were hot spots for Covid 19 and most hit by the pandemic in the province.',
#     'target': [73, 81],
#     'highest_similarity': 0.4034035364959587,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'extremely': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'extremely',
#     'sentence': 'A spokeswoman for Pfizer said Wednesday that the companys cold storage equipment was designed by securityconscious experts and custombuilt to match the specific requirements of Pfizers vaccine, which must be stored at extremely cold temperatures.',
#     'target': [218, 227],
#     'highest_similarity': 0.40385838369930616,
#     'corpus_id': 'leipzig_eng_news'}]},
#  'reflective': {'samples': 1,
#   'unassigned_usages': [{'lemma': 'reflective',
#     'sentence': "In one reflective moment in his speech yesterday, Boris acknowledged that at times the Government's response to coronavirus was seen as being like a 'recurring bad dream where you are telling your feet to run but your feet won't move.'",
#     'target': [7, 17],
#     'highest_similarity': 0.4048847096058937,
#     'corpus_id': 'leipzig_eng_news'}]}}

# %%
samples = 0
for lemma in sample:
    samples += sample[lemma]['samples']
print(f"Number of lemmas with samples: {len(sample)}")
print(f"Number of samples: {samples}")
# Out:
# Number of lemmas with samples: 115
# Number of samples: 332

# %%
with open("../data_sampling_2/data/annotation_data/combined_results.json", 'w') as f:
    json.dump(sample, f, indent=4)
